# %% [markdown]
# # Выводы после построения линейных моделей

# %%
import sys
import os
import pandas as pd

current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, ".."))

# Добавляем родительскую директорию в sys.path
sys.path.append(parent_dir)

from utils.utils import start, min_max_scaler, standard_scaler
from utils.generate_descriptors import (load_molecules, get_descriptors, remove_duplicates, remove_nan, 
                                    calc_all_descriptors, get_all_descriptors, remove_data_target)
from utils.functions_visualization import heatmap, display_images

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. Отбор признаков с помощью Lasso

# %%
display_images("./output_data/lasso")

# %% [markdown]
# --------------------------
#
# # Результаты Ridge

# %%
display_images("./output_data/ridge")

# %%
pd.read_csv("./results_ridge/ridge_logbcf.csv")
# Out:
#                  Model Размер тестовой выборки    R2  RMSE  \
# 0        RidgeMinMaxSc                     33%  0.64  0.80
# 1        RidgeMinMaxSc                     25%  0.65  0.76
# 2        RidgeMinMaxSc                     20%  0.67  0.78
# 3        RidgeMinMaxSc                     10%  0.73  0.75
# 4           RidgeStdSc                     33%  0.64  0.80
# 5           RidgeStdSc                     25%  0.65  0.76
# 6           RidgeStdSc                     20%  0.67  0.78
# 7           RidgeStdSc                     10%  0.73  0.75
# 8      RidgeLassoStdSc                     33%  0.67  0.76
# 9      RidgeLassoStdSc                     25%  0.66  0.74
# 10     RidgeLassoStdSc                     20%  0.71  0.68
# 11     RidgeLassoStdSc                     10%  0.58  0.78
# 12  RidgeLassoMinMaxSc                     33%  0.59  0.84
# 13  RidgeLassoMinMaxSc                     25%  0.57  0.82
# 14  RidgeLassoMinMaxSc                     20%  0.63  0.76
# ...

# %%
import pickle
with open("./output_data/models/pipeline_RidgeMinMaxSc_33%.pkl", 'rb') as transformer_file:
    transformer = pickle.load(transformer_file)

# %%
transformer
# Out:
# Pipeline(steps=[('scaler',
#                  Pipeline(steps=[('descriptors_generation',
#                                   FunctionTransformer(func=<function mol_dsc_calc at 0x0000028937869B20>)),
#                                  ('normalization', MinMaxScaler())])),
#                 ('model', Ridge(alpha=0.16, max_iter=10000, solver='svd'))])
